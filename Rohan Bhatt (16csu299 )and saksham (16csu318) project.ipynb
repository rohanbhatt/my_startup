# %%
######## comments are denoted as ## 
                                 # - this is the continuation of the comments okkk saksham

# %%
import numpy as np  ## before starting any  analysis we need tools for that purpose these tools are called packages import
import pandas as pd # is a command to get those packages one is numpy other one is pandas both are required
                    # pandas is required for analysis by making dataframe that are generally detemined by df in this project
                  # so it is written as df = pd.pandas(np.random.randn(4,5))
## now before  u this numpy is usually used for creating array and command is np.random.randn(4,5) means 4 rows
# and 5 columns okk. Now basically this is converted to dataframe and then we analyse it

# %%
import matplotlib.pyplot as plt
import seaborn as sns                ## these are for the purpose of showing graphically u need to just memorise it like
                                 # import matplotlib.pyplot as plt and same with seaborn okk later i will tell u how to use it.
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df = pd.read_csv('911.csv')  ### basically this is most imp parrt we r reading huge dataset from website kaggle okk and it is of
df                              # csv format okkkk saksham bhaiii
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %%
df.info() # before starting we r finding out the information regarding dataframe nothing more than that bhaii
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
# lat          99492 non-null float64
# lng          99492 non-null float64
# desc         99492 non-null object
# zip          86637 non-null float64
# title        99492 non-null object
# timeStamp    99492 non-null object
# twp          99449 non-null object
# addr         98973 non-null object
# e            99492 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df['zip'].value_counts().head(5) ## here we r just taking a column into consideration byh df['zip']
                                 # then using inbuilt function called value_counts()
                                 # head() is for starting data only showed plss
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: zip, dtype: int64

# %%
df['twp'].value_counts().head(5)
# Out:
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: twp, dtype: int64

# %%
df['twp'].value_counts().head(5)
# Out:
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: twp, dtype: int64

# %%
df['title'].nunique() # no of uniques in it
# Out:
# 110

# %%
df.describe()   ## it is a function on df(dataframe to tell us mean ,std, count)
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
df.sort_values(by='zip').head(5) #inplace=False by default ## data is sorted
# Out:
#              lat        lng  \
# 8367   41.167156 -76.874030
# 41689  40.453790 -75.459977
# 26763  40.456517 -75.463066
# 95602  40.403330 -75.510632
# 88215  40.392254 -75.515893
#
#                                                     desc      zip  \
# 8367       MAIN;  ; Station 308A; 2016-01-02 @ 13:01:30;  17752.0
# 41689  MILL HILL RD & ORCHARD RD;  LEHIGH COUNTY; Sta...  18036.0
# 26763  ORCHARD RD & SCHOOL HOUSE LN;  LEHIGH COUNTY; ...  18036.0
# 95602  COLONIAL DR & HAMILTON RD; EAST GREENVILLE; 20...  18041.0
# 88215  CHURCH RD;  UPPER HANOVER; Station 369; 2016-0...  18041.0
#
#                                 title            timeStamp              twp  \
# 8367   EMS: UNKNOWN MEDICAL EMERGENCY  2016-01-02 13:06:00              NaN
# 41689      EMS: RESPIRATORY EMERGENCY  2016-03-26 07:22:00    LEHIGH COUNTY
# 26763                    EMS: CHOKING  2016-02-15 16:07:01    LEHIGH COUNTY
# 95602     Traffic: VEHICLE ACCIDENT -  2016-08-14 09:42:02  EAST GREENVILLE
# ...

# %%
df.isnull().head(5) ## to show something is not null
# Out:
#      lat    lng   desc    zip  title  timeStamp    twp   addr      e
# 0  False  False  False  False  False      False  False  False  False
# 1  False  False  False  False  False      False  False  False  False
# 2  False  False  False  False  False      False  False  False  False
# 3  False  False  False  False  False      False  False  False  False
# 4  False  False  False   True  False      False  False  False  False

# %%
df['Reason'] = df['title'].apply(lambda title: title.split(':')[0])

# %%
df['Reason'].value_counts()
# Out:
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: Reason, dtype: int64

# %%
sns.countplot(x='Reason',data=df,palette='viridis') ## sns is nothing but seaborn (countplot is a function to count reason 
                                                    #columns , Show the counts of observations in each categorical bin using bars.

# %%
type(df['timeStamp'].iloc[0]) ## just to know the type and that is by iloc is basically used for rows index okk
# Out:
# str

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp']) ## to give us the datetime of it

# %%
df['Hour'] = df['timeStamp'].apply(lambda time: time.hour)
df['Month'] = df['timeStamp'].apply(lambda time: time.month)
df['Day of Week'] = df['timeStamp'].apply(lambda time: time.dayofweek)

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
byMonth = df.groupby('Month').count()
byMonth.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
# 2      11467  11467  11467   9930  11467      11467  11465  11396  11467
# 3      11101  11101  11101   9755  11101      11101  11092  11059  11101
# 4      11326  11326  11326   9895  11326      11326  11323  11283  11326
# 5      11423  11423  11423   9946  11423      11423  11420  11378  11423
#
#         Hour  Day of Week
# Month
# 1      13205        13205
# 2      11467        11467
# 3      11101        11101
# 4      11326        11326
# 5      11423        11423

# %%
# Could be any column
byMonth['twp'].plot() ## just right it down bymonth['twp'] # column name can be any and .plot()

# %%
byMonth['lng'].plot()   ## only this much brooo only this much

# %%
# now just use google and copy paste its content main part from our side is done bhaiiiiii
## enjoy man
